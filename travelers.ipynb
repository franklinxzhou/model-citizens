# %%
# %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/anaconda3/lib/python3.12/site-packages (3.1.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
import pandas as pd

train = pd.read_csv("./data/Training_TriGuard.csv")
test = pd.read_csv("./data/Testing_TriGuard.csv")

X_train = train.drop("subrogation", axis=1)
y_train = train["subrogation"]

X_test = test

from xgboost import XGBClassifier

# %%
train.head()
# Out:
#    claim_number  year_of_born gender  email_or_tel_available  safety_rating  \
# 0       3126034          1987      M                       0             68
# 1       7380142          1987      M                       1             78
# 2       4655051          1978      M                       1             72
# 3       6728725          1978      M                       0             67
# 4       9848460          1996      M                       1             81
#
#    annual_income  high_education_ind  address_change_ind living_status  \
# 0          30015                   1                   0           Own
# 1          30015                   1                   0          Rent
# 2          52206                   0                   1          Rent
# 3          52292                   0                   1           Own
# 4          41140                   0                   1           Own
#
#    zip_code  ... claim_est_payout vehicle_made_year vehicle_category  \
# 0     85036  ...          1373.91              2024          Compact
# 1     20148  ...           733.19              2026          Compact
# 2     20135  ...          5885.44              2026            Large
# 3     80015  ...           860.31              2022          Compact
# 4     85024  ...          4589.91              2024           Medium
#
#    vehicle_price vehicle_color  vehicle_weight age_of_DL        accident_type  \
# 0    15000.00000           red    10960.930390        25           single_car
# 1    26970.21435         other    13006.313970        22  multi_vehicle_clear
# 2    78773.76660         white    10541.156550        24           single_car
# 3    86166.37419          blue     2733.726122        21  multi_vehicle_clear
# 4    15000.00000          gray    18357.025300        18  multi_vehicle_clear
#
#    in_network_bodyshop  vehicle_mileage
# 0                  yes            86496
# 1                  yes            71936
# 2                  yes            84984
# 3                  yes            51583
# 4                   no           108488
#
# [5 rows x 28 columns]

# %%
test.head()
# Out:
#    claim_number  year_of_born gender  email_or_tel_available  safety_rating  \
# 0       3126034          1987      M                       0             68
# 1       7380142          1987      M                       1             78
# 2       4655051          1978      M                       1             72
# 3       6728725          1978      M                       0             67
# 4       9848460          1996      M                       1             81
#
#    annual_income  high_education_ind  address_change_ind living_status  \
# 0          30015                   1                   0           Own
# 1          30015                   1                   0          Rent
# 2          52206                   0                   1          Rent
# 3          52292                   0                   1           Own
# 4          41140                   0                   1           Own
#
#    zip_code  ... claim_est_payout vehicle_made_year vehicle_category  \
# 0     85036  ...          1373.91              2024          Compact
# 1     20148  ...           733.19              2026          Compact
# 2     20135  ...          5885.44              2026            Large
# 3     80015  ...           860.31              2022          Compact
# 4     85024  ...          4589.91              2024           Medium
#
#    vehicle_price vehicle_color  vehicle_weight age_of_DL        accident_type  \
# 0    15000.00000           red    10960.930390        25           single_car
# 1    26970.21435         other    13006.313970        22  multi_vehicle_clear
# 2    78773.76660         white    10541.156550        24           single_car
# 3    86166.37419          blue     2733.726122        21  multi_vehicle_clear
# 4    15000.00000          gray    18357.025300        18  multi_vehicle_clear
#
#    in_network_bodyshop  vehicle_mileage
# 0                  yes            86496
# 1                  yes            71936
# 2                  yes            84984
# 3                  yes            51583
# 4                   no           108488
#
# [5 rows x 28 columns]

# %%
import os
print(os.getcwd())  # 当前工作目录
print(os.listdir()) # 当前目录下的文件
# Out:
# /Users/gracewu/Desktop/model-citizens
# ['.DS_Store', 'travelers.ipynb', '.git', 'data']
